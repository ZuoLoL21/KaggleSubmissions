# %%
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
# Out:
# C:\Users\zuolo\anaconda3\envs\tensor_data_science\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
from common.libs.data_analysis.SeriesDescriberWRTTarget import *
from common.classes.DataGenerators import SeqDataGeneratorList
from common.classes.CustomCallbacks import BatchMetricsCallback
from common.libs.CustomScalers import get_log1_scaler

# %%
def plot_graph(
        x,
        *ys,
        x_label: str = "x",
        y_label: str = "y",
        jumps: int = 1000,
        labels: list = cycle(['']),
):
    for y, label in zip(ys, chain(labels, cycle(['']))):
        plt.plot(range(len(y)), y, label=label)
    plt.xticks(range(0, len(x), jumps), x[::jumps], rotation=45)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    # plt.legend()
    plt.show()

# %%
stock_df = pd.read_csv('inputs/hpq.us.txt',
                       delimiter=',',
                       usecols=['Date', 'Open', 'High', 'Low', 'Close'])
stock_df = stock_df.sort_values('Date')
stock_df.head()
# Out:
#          Date     Open     High      Low    Close
# 0  1970-01-02  0.30627  0.30627  0.30627  0.30627
# 1  1970-01-05  0.30627  0.31768  0.30627  0.31385
# 2  1970-01-06  0.31385  0.31385  0.30996  0.30996
# 3  1970-01-07  0.31385  0.31385  0.31385  0.31385
# 4  1970-01-08  0.31385  0.31768  0.31385  0.31385

# %%
high_prices = stock_df['High'].to_numpy()
low_prices = stock_df['Low'].to_numpy()
mid_prices = (high_prices + low_prices) / 2.0

plot_graph(stock_df['Date'], mid_prices, x_label='Time', y_label='Mid Prices')

train_data = mid_prices[:11000]
test_data = mid_prices[11000:]

train_data = np.expand_dims(train_data, axis=1)
test_data = np.expand_dims(test_data, axis=1)

# Log Scale
log_scaler = get_log1_scaler(validate=True)
train_data = log_scaler.transform(train_data)
test_data = log_scaler.transform(test_data)

# Min Max Scale
scaler = MinMaxScaler()
scaler.fit(train_data)
train_data = np.squeeze(scaler.transform(train_data))
test_data = np.squeeze(scaler.transform(test_data))

# Moving average
EMA = 0.0
gamma = 0.1
for ti in range(train_data.shape[0]):
    EMA = gamma * train_data[ti] + (1 - gamma) * EMA
train_data[ti] = EMA

concatenated_mid_data = np.concatenate((train_data, test_data), axis=0)
plot_graph(stock_df['Date'], concatenated_mid_data, x_label='Time', y_label='Mid Price')

# %%
D = 1  # Dimensionality of the data. Since your data is 1-D this would be 1
num_unrollings = 50  # Number of time steps you look into the future.
batch_size = 200  # Number of samples in a batch
num_nodes = [200, 200, 150]  # Number of hidden nodes in each layer of the deep LSTM stack we're using
n_layers = len(num_nodes)  # number of layers
dropout = 0.2  # dropout amount

tf.compat.v1.reset_default_graph()  # This is important in case you run this multiple times
# Out:
# WARNING:tensorflow:From C:\Users\zuolo\AppData\Local\Temp\ipykernel_25424\1836326611.py:8: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
# Input data.
dg = SeqDataGeneratorList(train_data, batch_size, num_unrollings)
train_inputs, train_outputs = dg.unroll_batches()

print(train_inputs.shape)
print(train_outputs.shape)
# Out:
# (200, 50, 1)
# (200, 1)

# %%
layers = [tf.keras.layers.Input(shape=(train_inputs.shape[1], train_inputs.shape[2])),
          *[tf.keras.layers.LSTM(
                  num_nodes[layer],
                  return_sequences=(layer < n_layers - 1)
          ) for layer in range(n_layers)],
          tf.keras.layers.Dense(1)]

model = tf.keras.Sequential(layers)

model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss='mse',
        metrics=[
            'mae'
        ]
)
# Cant use F1 cuz not categorical data

# %%
epochs = 100
dataset = tf.data.Dataset.from_generator(
        dg.as_generator(),
        output_signature=(
            tf.TensorSpec(shape=train_inputs.shape, dtype=tf.float32),
            tf.TensorSpec(shape=train_outputs.shape, dtype=tf.float32)
        )
)
# Train using model.fit with dataset
callback = BatchMetricsCallback()
history = model.fit(
        dataset,
        epochs=epochs,
        steps_per_epoch=1,
        callbacks=[callback],
        verbose=2
)
# Out:
# Epoch 1/100
# 1/1 - 2s - 2s/step - loss: 0.2887 - mae: 0.4581
# Epoch 2/100
# 1/1 - 0s - 411ms/step - loss: 0.0912 - mae: 0.2404
# Epoch 3/100
# 1/1 - 0s - 338ms/step - loss: 0.0075 - mae: 0.0849
# Epoch 4/100
# 1/1 - 0s - 305ms/step - loss: 0.0430 - mae: 0.1985
# Epoch 5/100
# 1/1 - 0s - 278ms/step - loss: 0.0041 - mae: 0.0540
# Epoch 6/100
# 1/1 - 0s - 365ms/step - loss: 0.0258 - mae: 0.1242
# Epoch 7/100
# 1/1 - 0s - 363ms/step - loss: 0.0309 - mae: 0.1394
# Epoch 8/100
# 1/1 - 0s - 274ms/step - loss: 0.0183 - mae: 0.1090
# Epoch 9/100
# 1/1 - 0s - 257ms/step - loss: 0.0037 - mae: 0.0538
# Epoch 10/100
# 1/1 - 0s - 246ms/step - loss: 0.0100 - mae: 0.0986
# Epoch 11/100
# 1/1 - 0s - 248ms/step - loss: 0.0196 - mae: 0.1379
# Epoch 12/100
# 1/1 - 0s - 332ms/step - loss: 0.0085 - mae: 0.0912
# Epoch 13/100
# 1/1 - 0s - 262ms/step - loss: 0.0025 - mae: 0.0443
# Epoch 14/100
# 1/1 - 0s - 357ms/step - loss: 0.0055 - mae: 0.0608
# Epoch 15/100
# 1/1 - 0s - 362ms/step - loss: 0.0109 - mae: 0.0862
# Epoch 16/100
# 1/1 - 0s - 388ms/step - loss: 0.0086 - mae: 0.0748
# Epoch 17/100
# 1/1 - 0s - 348ms/step - loss: 0.0056 - mae: 0.0601
# Epoch 18/100
# 1/1 - 0s - 243ms/step - loss: 0.0025 - mae: 0.0421
# Epoch 19/100
# 1/1 - 0s - 235ms/step - loss: 0.0015 - mae: 0.0342
# Epoch 20/100
# 1/1 - 0s - 267ms/step - loss: 0.0042 - mae: 0.0629
# Epoch 21/100
# 1/1 - 0s - 387ms/step - loss: 0.0061 - mae: 0.0751
# Epoch 22/100
# 1/1 - 0s - 233ms/step - loss: 0.0032 - mae: 0.0549
# Epoch 23/100
# 1/1 - 0s - 214ms/step - loss: 8.5859e-04 - mae: 0.0255
# Epoch 24/100
# 1/1 - 0s - 216ms/step - loss: 6.8547e-04 - mae: 0.0198
# Epoch 25/100
# 1/1 - 0s - 272ms/step - loss: 0.0018 - mae: 0.0312
# Epoch 26/100
# 1/1 - 0s - 230ms/step - loss: 0.0031 - mae: 0.0448
# Epoch 27/100
# 1/1 - 0s - 262ms/step - loss: 0.0026 - mae: 0.0416
# Epoch 28/100
# 1/1 - 0s - 280ms/step - loss: 0.0011 - mae: 0.0280
# Epoch 29/100
# 1/1 - 0s - 390ms/step - loss: 1.8834e-04 - mae: 0.0111
# Epoch 30/100
# 1/1 - 0s - 323ms/step - loss: 5.8352e-04 - mae: 0.0191
# Epoch 31/100
# 1/1 - 0s - 297ms/step - loss: 0.0015 - mae: 0.0311
# Epoch 32/100
# 1/1 - 0s - 313ms/step - loss: 0.0022 - mae: 0.0396
# Epoch 33/100
# 1/1 - 0s - 290ms/step - loss: 8.8591e-04 - mae: 0.0232
# Epoch 34/100
# 1/1 - 0s - 404ms/step - loss: 3.0589e-04 - mae: 0.0137
# Epoch 35/100
# 1/1 - 0s - 474ms/step - loss: 6.6719e-04 - mae: 0.0226
# Epoch 36/100
# 1/1 - 0s - 318ms/step - loss: 0.0011 - mae: 0.0303
# Epoch 37/100
# 1/1 - 0s - 200ms/step - loss: 0.0014 - mae: 0.0339
# Epoch 38/100
# 1/1 - 0s - 270ms/step - loss: 9.4199e-04 - mae: 0.0271
# Epoch 39/100
# 1/1 - 0s - 292ms/step - loss: 3.8807e-04 - mae: 0.0158
# Epoch 40/100
# 1/1 - 0s - 293ms/step - loss: 2.9931e-04 - mae: 0.0138
# Epoch 41/100
# 1/1 - 0s - 212ms/step - loss: 8.5019e-04 - mae: 0.0236
# Epoch 42/100
# 1/1 - 0s - 259ms/step - loss: 0.0012 - mae: 0.0280
# Epoch 43/100
# 1/1 - 0s - 256ms/step - loss: 6.9147e-04 - mae: 0.0200
# Epoch 44/100
# 1/1 - 0s - 205ms/step - loss: 3.6243e-04 - mae: 0.0128
# Epoch 45/100
# 1/1 - 0s - 203ms/step - loss: 3.4061e-04 - mae: 0.0145
# Epoch 46/100
# 1/1 - 0s - 282ms/step - loss: 5.5243e-04 - mae: 0.0188
# Epoch 47/100
# 1/1 - 0s - 255ms/step - loss: 7.5054e-04 - mae: 0.0214
# Epoch 48/100
# 1/1 - 0s - 226ms/step - loss: 6.1637e-04 - mae: 0.0189
# Epoch 49/100
# 1/1 - 0s - 204ms/step - loss: 2.8859e-04 - mae: 0.0128
# Epoch 50/100
# 1/1 - 0s - 226ms/step - loss: 2.8261e-04 - mae: 0.0123
# Epoch 51/100
# 1/1 - 0s - 268ms/step - loss: 4.8549e-04 - mae: 0.0172
# Epoch 52/100
# 1/1 - 0s - 294ms/step - loss: 6.4245e-04 - mae: 0.0209
# Epoch 53/100
# 1/1 - 0s - 294ms/step - loss: 4.4161e-04 - mae: 0.0163
# Epoch 54/100
# 1/1 - 0s - 238ms/step - loss: 2.0585e-04 - mae: 0.0106
# Epoch 55/100
# 1/1 - 0s - 358ms/step - loss: 2.7109e-04 - mae: 0.0121
# Epoch 56/100
# 1/1 - 0s - 245ms/step - loss: 3.8427e-04 - mae: 0.0137
# Epoch 57/100
# 1/1 - 0s - 227ms/step - loss: 4.6070e-04 - mae: 0.0152
# Epoch 58/100
# 1/1 - 0s - 244ms/step - loss: 3.2887e-04 - mae: 0.0122
# Epoch 59/100
# 1/1 - 0s - 250ms/step - loss: 1.5507e-04 - mae: 0.0095
# Epoch 60/100
# 1/1 - 0s - 209ms/step - loss: 2.3569e-04 - mae: 0.0110
# Epoch 61/100
# 1/1 - 0s - 225ms/step - loss: 3.1867e-04 - mae: 0.0133
# Epoch 62/100
# 1/1 - 0s - 231ms/step - loss: 2.7066e-04 - mae: 0.0121
# Epoch 63/100
# 1/1 - 0s - 278ms/step - loss: 3.0214e-04 - mae: 0.0125
# Epoch 64/100
# 1/1 - 0s - 234ms/step - loss: 1.6544e-04 - mae: 0.0093
# Epoch 65/100
# 1/1 - 0s - 263ms/step - loss: 1.9485e-04 - mae: 0.0103
# Epoch 66/100
# 1/1 - 0s - 273ms/step - loss: 2.3979e-04 - mae: 0.0118
# Epoch 67/100
# 1/1 - 0s - 279ms/step - loss: 2.8034e-04 - mae: 0.0124
# Epoch 68/100
# 1/1 - 0s - 233ms/step - loss: 2.1239e-04 - mae: 0.0110
# Epoch 69/100
# 1/1 - 0s - 286ms/step - loss: 1.9926e-04 - mae: 0.0103
# Epoch 70/100
# 1/1 - 0s - 345ms/step - loss: 2.4663e-04 - mae: 0.0113
# Epoch 71/100
# 1/1 - 0s - 302ms/step - loss: 1.7060e-04 - mae: 0.0098
# Epoch 72/100
# 1/1 - 0s - 431ms/step - loss: 1.9447e-04 - mae: 0.0102
# Epoch 73/100
# 1/1 - 0s - 309ms/step - loss: 1.5866e-04 - mae: 0.0099
# Epoch 74/100
# 1/1 - 0s - 295ms/step - loss: 1.6001e-04 - mae: 0.0092
# Epoch 75/100
# 1/1 - 0s - 295ms/step - loss: 1.5795e-04 - mae: 0.0093
# Epoch 76/100
# 1/1 - 0s - 297ms/step - loss: 2.4904e-04 - mae: 0.0120
# Epoch 77/100
# 1/1 - 0s - 316ms/step - loss: 1.4985e-04 - mae: 0.0094
# Epoch 78/100
# 1/1 - 0s - 439ms/step - loss: 1.5247e-04 - mae: 0.0094
# Epoch 79/100
# 1/1 - 0s - 346ms/step - loss: 1.6813e-04 - mae: 0.0095
# Epoch 80/100
# 1/1 - 0s - 327ms/step - loss: 1.7622e-04 - mae: 0.0094
# Epoch 81/100
# 1/1 - 0s - 315ms/step - loss: 2.1601e-04 - mae: 0.0109
# Epoch 82/100
# 1/1 - 0s - 348ms/step - loss: 2.0429e-04 - mae: 0.0109
# Epoch 83/100
# 1/1 - 0s - 312ms/step - loss: 1.9747e-04 - mae: 0.0101
# Epoch 84/100
# 1/1 - 0s - 332ms/step - loss: 1.8502e-04 - mae: 0.0099
# Epoch 85/100
# 1/1 - 0s - 335ms/step - loss: 2.4785e-04 - mae: 0.0108
# Epoch 86/100
# 1/1 - 0s - 255ms/step - loss: 2.4786e-04 - mae: 0.0108
# Epoch 87/100
# 1/1 - 0s - 282ms/step - loss: 2.1517e-04 - mae: 0.0101
# Epoch 88/100
# 1/1 - 0s - 275ms/step - loss: 1.8764e-04 - mae: 0.0094
# Epoch 89/100
# 1/1 - 0s - 295ms/step - loss: 1.3933e-04 - mae: 0.0088
# Epoch 90/100
# 1/1 - 0s - 299ms/step - loss: 1.9522e-04 - mae: 0.0099
# Epoch 91/100
# 1/1 - 0s - 411ms/step - loss: 2.1568e-04 - mae: 0.0104
# Epoch 92/100
# 1/1 - 0s - 267ms/step - loss: 1.7801e-04 - mae: 0.0095
# Epoch 93/100
# 1/1 - 0s - 259ms/step - loss: 1.3749e-04 - mae: 0.0086
# Epoch 94/100
# 1/1 - 0s - 288ms/step - loss: 1.9118e-04 - mae: 0.0102
# Epoch 95/100
# 1/1 - 0s - 272ms/step - loss: 2.8402e-04 - mae: 0.0120
# Epoch 96/100
# 1/1 - 0s - 269ms/step - loss: 1.9207e-04 - mae: 0.0100
# Epoch 97/100
# 1/1 - 0s - 286ms/step - loss: 2.0442e-04 - mae: 0.0091
# Epoch 98/100
# 1/1 - 0s - 313ms/step - loss: 2.3676e-04 - mae: 0.0097
# Epoch 99/100
# 1/1 - 0s - 262ms/step - loss: 2.2974e-04 - mae: 0.0106
# Epoch 100/100
# 1/1 - 0s - 253ms/step - loss: 1.6254e-04 - mae: 0.0085

# %%
plt.plot(callback.batch_losses, label='mse')
plt.plot(callback.batch_maes, label='mae')
plt.legend()
plt.show()

# %%
print(test_data.shape)
test_generator = SeqDataGeneratorList(test_data, 1000, num_unrollings)

test_input, test_output = test_generator.unroll_batches()

test_pred = model.predict(test_input, verbose=0)

loss = tf.keras.losses.mse(test_output, test_pred)
loss = tf.reduce_mean(loss).numpy()
print(loss)
# Out:
# (1075,)
# 0.00018327708

# %%
plt.plot(callback.batch_losses, label='mse')
plt.plot([loss] * len(callback.batch_losses), label='test_error')
plt.ylim(0, 0.001)
plt.legend()
plt.show()
