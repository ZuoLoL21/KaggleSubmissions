# %%
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
# Out:
# C:\Users\zuolo\anaconda3\envs\tensor_data_science\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
from common.libs.data_analysis.SeriesDescriberWRTTarget import *
from common.classes.DataGenerators import DataGeneratorSeq
from common.classes.CustomCallbacks import BatchMetricsCallback
from common.libs.CustomScalers import get_log1_scaler

# %%
def plot_graph(
        x,
        *ys,
        x_label: str = "x",
        y_label: str = "y",
        jumps: int = 1000,
        labels: list = cycle(['']),
):
    for y, label in zip(ys, chain(labels, cycle(['']))):
        plt.plot(range(len(y)), y, label=label)
    plt.xticks(range(0, len(x), jumps), x[::jumps], rotation=45)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    # plt.legend()
    plt.show()

# %%
stock_df = pd.read_csv('inputs/hpq.us.txt',
                       delimiter=',',
                       usecols=['Date', 'Open', 'High', 'Low', 'Close'])
stock_df = stock_df.sort_values('Date')
stock_df.head()
# Out:
#          Date     Open     High      Low    Close
# 0  1970-01-02  0.30627  0.30627  0.30627  0.30627
# 1  1970-01-05  0.30627  0.31768  0.30627  0.31385
# 2  1970-01-06  0.31385  0.31385  0.30996  0.30996
# 3  1970-01-07  0.31385  0.31385  0.31385  0.31385
# 4  1970-01-08  0.31385  0.31768  0.31385  0.31385

# %%
high_prices = stock_df['High'].to_numpy()
low_prices = stock_df['Low'].to_numpy()
mid_prices = (high_prices + low_prices) / 2.0

plot_graph(stock_df['Date'], mid_prices, x_label='Time', y_label='Mid Prices')

train_data = mid_prices[:11000]
test_data = mid_prices[11000:]

train_data = np.expand_dims(train_data, axis=1)
test_data = np.expand_dims(test_data, axis=1)

# Log Scale
log_scaler = get_log1_scaler(validate=True)
train_data = log_scaler.transform(train_data)
test_data = log_scaler.transform(test_data)

# Min Max Scale
scaler = MinMaxScaler()
scaler.fit(train_data)
train_data = np.squeeze(scaler.transform(train_data))
test_data = np.squeeze(scaler.transform(test_data))

# Moving average
EMA = 0.0
gamma = 0.1
for ti in range(train_data.shape[0]):
    EMA = gamma * train_data[ti] + (1 - gamma) * EMA
train_data[ti] = EMA

concatenated_mid_data = np.concatenate((train_data, test_data), axis=0)
plot_graph(stock_df['Date'], concatenated_mid_data, x_label='Time', y_label='Mid Price')

# %%
D = 1  # Dimensionality of the data. Since your data is 1-D this would be 1
num_unrollings = 50  # Number of time steps you look into the future.
batch_size = 200  # Number of samples in a batch
num_nodes = [200, 200, 150]  # Number of hidden nodes in each layer of the deep LSTM stack we're using
n_layers = len(num_nodes)  # number of layers
dropout = 0.2  # dropout amount

tf.compat.v1.reset_default_graph()  # This is important in case you run this multiple times
# Out:
# WARNING:tensorflow:From C:\Users\zuolo\AppData\Local\Temp\ipykernel_16708\1836326611.py:8: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
# Input data.
dg = DataGeneratorSeq(train_data, batch_size, num_unrollings)
train_inputs, train_outputs = dg.unroll_batches()

print(train_inputs.shape)
print(train_outputs.shape)
# Out:
# (200, 50, 1)
# (200, 1)

# %%
layers = [tf.keras.layers.Input(shape=(train_inputs.shape[1], train_inputs.shape[2])),
          *[tf.keras.layers.LSTM(
                  num_nodes[layer],
                  return_sequences=(layer < n_layers - 1)
          ) for layer in range(n_layers)],
          tf.keras.layers.Dense(1)]

model = tf.keras.Sequential(layers)

model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss='mse',
        metrics=[
            'mae'
        ]
)
# Cant use F1 cuz not categorical data

# %%
epochs = 100
dataset = tf.data.Dataset.from_generator(
        dg.as_generator(),
        output_signature=(
            tf.TensorSpec(shape=train_inputs.shape, dtype=tf.float32),
            tf.TensorSpec(shape=train_outputs.shape, dtype=tf.float32)
        )
)
# Train using model.fit with dataset
callback = BatchMetricsCallback()
history = model.fit(
        dataset,
        epochs=epochs,
        steps_per_epoch=1,
        callbacks=[callback],
        verbose=2
)
# Out:
# Epoch 1/100
# 1/1 - 2s - 2s/step - loss: 0.2402 - mae: 0.4023
# Epoch 2/100
# 1/1 - 0s - 298ms/step - loss: 0.0790 - mae: 0.2287
# Epoch 3/100
# 1/1 - 0s - 261ms/step - loss: 0.0317 - mae: 0.1706
# Epoch 4/100
# 1/1 - 0s - 260ms/step - loss: 0.0055 - mae: 0.0715
# Epoch 5/100
# 1/1 - 0s - 271ms/step - loss: 0.0099 - mae: 0.0788
# Epoch 6/100
# 1/1 - 0s - 259ms/step - loss: 0.0198 - mae: 0.1135
# Epoch 7/100
# 1/1 - 0s - 294ms/step - loss: 0.0081 - mae: 0.0738
# Epoch 8/100
# 1/1 - 0s - 303ms/step - loss: 0.0026 - mae: 0.0442
# Epoch 9/100
# 1/1 - 0s - 256ms/step - loss: 0.0104 - mae: 0.1007
# Epoch 10/100
# 1/1 - 0s - 305ms/step - loss: 0.0080 - mae: 0.0880
# Epoch 11/100
# 1/1 - 0s - 265ms/step - loss: 0.0019 - mae: 0.0389
# Epoch 12/100
# 1/1 - 0s - 302ms/step - loss: 0.0038 - mae: 0.0493
# Epoch 13/100
# 1/1 - 0s - 302ms/step - loss: 0.0066 - mae: 0.0645
# Epoch 14/100
# 1/1 - 0s - 363ms/step - loss: 0.0046 - mae: 0.0533
# Epoch 15/100
# 1/1 - 0s - 387ms/step - loss: 0.0013 - mae: 0.0300
# Epoch 16/100
# 1/1 - 0s - 356ms/step - loss: 0.0012 - mae: 0.0323
# Epoch 17/100
# 1/1 - 0s - 312ms/step - loss: 0.0034 - mae: 0.0556
# Epoch 18/100
# 1/1 - 0s - 340ms/step - loss: 0.0028 - mae: 0.0494
# Epoch 19/100
# 1/1 - 0s - 310ms/step - loss: 3.9299e-04 - mae: 0.0165
# Epoch 20/100
# 1/1 - 0s - 218ms/step - loss: 8.8155e-04 - mae: 0.0221
# Epoch 21/100
# 1/1 - 0s - 239ms/step - loss: 0.0021 - mae: 0.0371
# Epoch 22/100
# 1/1 - 0s - 247ms/step - loss: 0.0019 - mae: 0.0363
# Epoch 23/100
# 1/1 - 0s - 273ms/step - loss: 5.4765e-04 - mae: 0.0198
# Epoch 24/100
# 1/1 - 0s - 334ms/step - loss: 3.5698e-04 - mae: 0.0146
# Epoch 25/100
# 1/1 - 0s - 285ms/step - loss: 0.0010 - mae: 0.0259
# Epoch 26/100
# 1/1 - 0s - 294ms/step - loss: 0.0017 - mae: 0.0332
# Epoch 27/100
# 1/1 - 0s - 312ms/step - loss: 6.5507e-04 - mae: 0.0196
# Epoch 28/100
# 1/1 - 0s - 354ms/step - loss: 4.0523e-04 - mae: 0.0177
# Epoch 29/100
# 1/1 - 0s - 289ms/step - loss: 9.5568e-04 - mae: 0.0285
# Epoch 30/100
# 1/1 - 0s - 367ms/step - loss: 0.0013 - mae: 0.0325
# Epoch 31/100
# 1/1 - 0s - 281ms/step - loss: 6.2013e-04 - mae: 0.0214
# Epoch 32/100
# 1/1 - 0s - 273ms/step - loss: 2.5683e-04 - mae: 0.0133
# Epoch 33/100
# 1/1 - 0s - 317ms/step - loss: 7.0952e-04 - mae: 0.0215
# Epoch 34/100
# 1/1 - 0s - 288ms/step - loss: 9.4259e-04 - mae: 0.0251
# Epoch 35/100
# 1/1 - 0s - 320ms/step - loss: 5.8680e-04 - mae: 0.0168
# Epoch 36/100
# 1/1 - 0s - 211ms/step - loss: 2.0853e-04 - mae: 0.0113
# Epoch 37/100
# 1/1 - 0s - 271ms/step - loss: 5.2782e-04 - mae: 0.0184
# Epoch 38/100
# 1/1 - 0s - 323ms/step - loss: 6.7040e-04 - mae: 0.0207
# Epoch 39/100
# 1/1 - 0s - 308ms/step - loss: 3.9106e-04 - mae: 0.0150
# Epoch 40/100
# 1/1 - 0s - 244ms/step - loss: 2.2608e-04 - mae: 0.0103
# Epoch 41/100
# 1/1 - 0s - 285ms/step - loss: 3.7984e-04 - mae: 0.0149
# Epoch 42/100
# 1/1 - 0s - 233ms/step - loss: 3.7330e-04 - mae: 0.0159
# Epoch 43/100
# 1/1 - 0s - 276ms/step - loss: 3.3416e-04 - mae: 0.0139
# Epoch 44/100
# 1/1 - 0s - 301ms/step - loss: 1.9010e-04 - mae: 0.0104
# Epoch 45/100
# 1/1 - 0s - 271ms/step - loss: 2.3549e-04 - mae: 0.0111
# Epoch 46/100
# 1/1 - 0s - 254ms/step - loss: 4.3552e-04 - mae: 0.0150
# Epoch 47/100
# 1/1 - 0s - 267ms/step - loss: 3.9603e-04 - mae: 0.0144
# Epoch 48/100
# 1/1 - 0s - 286ms/step - loss: 2.9572e-04 - mae: 0.0121
# Epoch 49/100
# 1/1 - 0s - 263ms/step - loss: 3.0984e-04 - mae: 0.0123
# Epoch 50/100
# 1/1 - 0s - 293ms/step - loss: 3.7639e-04 - mae: 0.0157
# Epoch 51/100
# 1/1 - 0s - 261ms/step - loss: 2.1276e-04 - mae: 0.0113
# Epoch 52/100
# 1/1 - 0s - 312ms/step - loss: 1.7982e-04 - mae: 0.0103
# Epoch 53/100
# 1/1 - 0s - 268ms/step - loss: 2.5881e-04 - mae: 0.0111
# Epoch 54/100
# 1/1 - 0s - 262ms/step - loss: 3.1689e-04 - mae: 0.0126
# Epoch 55/100
# 1/1 - 0s - 241ms/step - loss: 2.0665e-04 - mae: 0.0104
# Epoch 56/100
# 1/1 - 0s - 207ms/step - loss: 1.8686e-04 - mae: 0.0101
# Epoch 57/100
# 1/1 - 0s - 216ms/step - loss: 2.4563e-04 - mae: 0.0110
# Epoch 58/100
# 1/1 - 0s - 228ms/step - loss: 1.9010e-04 - mae: 0.0098
# Epoch 59/100
# 1/1 - 0s - 244ms/step - loss: 1.7565e-04 - mae: 0.0096
# Epoch 60/100
# 1/1 - 0s - 243ms/step - loss: 2.2532e-04 - mae: 0.0101
# Epoch 61/100
# 1/1 - 0s - 233ms/step - loss: 2.5475e-04 - mae: 0.0110
# Epoch 62/100
# 1/1 - 0s - 260ms/step - loss: 1.5505e-04 - mae: 0.0095
# Epoch 63/100
# 1/1 - 0s - 240ms/step - loss: 1.4631e-04 - mae: 0.0095
# Epoch 64/100
# 1/1 - 0s - 286ms/step - loss: 1.7381e-04 - mae: 0.0096
# Epoch 65/100
# 1/1 - 0s - 208ms/step - loss: 1.9448e-04 - mae: 0.0103
# Epoch 66/100
# 1/1 - 0s - 229ms/step - loss: 2.0642e-04 - mae: 0.0101
# Epoch 67/100
# 1/1 - 0s - 252ms/step - loss: 2.3914e-04 - mae: 0.0103
# Epoch 68/100
# 1/1 - 0s - 250ms/step - loss: 2.1206e-04 - mae: 0.0108
# Epoch 69/100
# 1/1 - 0s - 252ms/step - loss: 1.6201e-04 - mae: 0.0096
# Epoch 70/100
# 1/1 - 0s - 242ms/step - loss: 1.6186e-04 - mae: 0.0093
# Epoch 71/100
# 1/1 - 0s - 241ms/step - loss: 1.8182e-04 - mae: 0.0094
# Epoch 72/100
# 1/1 - 0s - 255ms/step - loss: 1.7979e-04 - mae: 0.0097
# Epoch 73/100
# 1/1 - 0s - 252ms/step - loss: 2.0676e-04 - mae: 0.0101
# Epoch 74/100
# 1/1 - 0s - 211ms/step - loss: 1.8756e-04 - mae: 0.0096
# Epoch 75/100
# 1/1 - 0s - 214ms/step - loss: 1.9230e-04 - mae: 0.0101
# Epoch 76/100
# 1/1 - 0s - 224ms/step - loss: 1.3496e-04 - mae: 0.0087
# Epoch 77/100
# 1/1 - 0s - 232ms/step - loss: 1.6805e-04 - mae: 0.0093
# Epoch 78/100
# 1/1 - 0s - 257ms/step - loss: 1.3731e-04 - mae: 0.0084
# Epoch 79/100
# 1/1 - 0s - 273ms/step - loss: 1.9585e-04 - mae: 0.0101
# Epoch 80/100
# 1/1 - 0s - 292ms/step - loss: 1.7616e-04 - mae: 0.0086
# Epoch 81/100
# 1/1 - 0s - 250ms/step - loss: 1.9249e-04 - mae: 0.0093
# Epoch 82/100
# 1/1 - 0s - 271ms/step - loss: 1.7682e-04 - mae: 0.0092
# Epoch 83/100
# 1/1 - 0s - 218ms/step - loss: 2.3476e-04 - mae: 0.0104
# Epoch 84/100
# 1/1 - 0s - 233ms/step - loss: 1.5267e-04 - mae: 0.0089
# Epoch 85/100
# 1/1 - 0s - 266ms/step - loss: 1.8401e-04 - mae: 0.0095
# Epoch 86/100
# 1/1 - 0s - 287ms/step - loss: 1.5651e-04 - mae: 0.0090
# Epoch 87/100
# 1/1 - 0s - 239ms/step - loss: 1.3096e-04 - mae: 0.0085
# Epoch 88/100
# 1/1 - 0s - 233ms/step - loss: 1.2618e-04 - mae: 0.0082
# Epoch 89/100
# 1/1 - 0s - 217ms/step - loss: 1.5191e-04 - mae: 0.0085
# Epoch 90/100
# 1/1 - 0s - 198ms/step - loss: 1.9029e-04 - mae: 0.0093
# Epoch 91/100
# 1/1 - 0s - 291ms/step - loss: 1.6377e-04 - mae: 0.0089
# Epoch 92/100
# 1/1 - 0s - 297ms/step - loss: 2.0730e-04 - mae: 0.0101
# Epoch 93/100
# 1/1 - 0s - 236ms/step - loss: 1.9351e-04 - mae: 0.0104
# Epoch 94/100
# 1/1 - 0s - 245ms/step - loss: 1.6716e-04 - mae: 0.0090
# Epoch 95/100
# 1/1 - 0s - 262ms/step - loss: 2.0574e-04 - mae: 0.0101
# Epoch 96/100
# 1/1 - 0s - 247ms/step - loss: 2.3335e-04 - mae: 0.0099
# Epoch 97/100
# 1/1 - 0s - 281ms/step - loss: 1.6611e-04 - mae: 0.0089
# Epoch 98/100
# 1/1 - 0s - 240ms/step - loss: 1.6137e-04 - mae: 0.0090
# Epoch 99/100
# 1/1 - 0s - 232ms/step - loss: 1.3622e-04 - mae: 0.0087
# Epoch 100/100
# 1/1 - 0s - 218ms/step - loss: 1.5899e-04 - mae: 0.0093

# %%
plt.plot(callback.batch_losses, label='mse')
plt.plot(callback.batch_maes, label='mae')
plt.legend()
plt.show()

# %%
print(test_data.shape)
test_generator = DataGeneratorSeq(test_data, 1000, num_unrollings)

test_input, test_output = test_generator.unroll_batches()

test_pred = model.predict(test_input, verbose=0)

loss = tf.keras.losses.mse(test_output, test_pred)
loss = tf.reduce_mean(loss).numpy()
print(loss)
# Out:
# (1075,)
# 0.00016225157

# %%
plt.plot(callback.batch_losses, label='mse')
plt.plot([loss] * len(callback.batch_losses), label='test_error')
plt.ylim(0, 0.001)
plt.legend()
plt.show()
